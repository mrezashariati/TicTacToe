# %%
import numpy as np

import math
from entities import Board
from learning import State, Action
import random

np.random.seed(28)
random.seed(28)

# %%
a = np.random.randint(low=0, high=3, size=(3,3)).astype(np.int16).reshape(-1)
astate = State(a)
aaction = Action(1)

d = dict()
d[(astate, aaction)] = 0.1
d
# Out:
# {(State(s=array([1, 1, 1, 2, 0, 0, 0, 0, 0], dtype=int16)), Action(a=1)): 0.1}

# %%
d[(State(s=np.array([1,1,1,2,0,0,0,0,0])), Action(1))]
# Out:
# 0.1
